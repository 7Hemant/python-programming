# %%
for x in range(1,6):
    for y in range(1,6):
        print("*",end=" ")
    print()
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
for x in range(1,6):
    for y in range(1,6):
        print(y,end="")
    print()
# Out:
# 12345
# 12345
# 12345
# 12345
# 12345

# %%
for x in range(1,6):
    for y in range(1,6):
        print(x,end="")
    print()
# Out:
# 11111
# 22222
# 33333
# 44444
# 55555

# %%
for i in range(1,6):
    for  j in range(0,i):
        print(i,end="")
    print()
# Out:
# 1
# 22
# 333
# 4444
# 55555

# %%
for i in range(1,6):
    for j in range(i,6):
        print(j,end="")
    print()
# Out:
# 12345
# 2345
# 345
# 45
# 5

# %%
for i in range(1,6):
    for j in range(i,6):
        print(i,end="")
    print()
# Out:
# 11111
# 2222
# 333
# 44
# 5
